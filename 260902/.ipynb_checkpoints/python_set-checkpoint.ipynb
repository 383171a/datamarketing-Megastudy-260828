# %% [markdown]
# ### 변수 & 자료형
# 1. 기본자료형
# - int : 정수
# - float : 실수
# - str : 문자열
# - bool : 논리형
# 2. 자료구조
# - list : [] / list()
# - tuple : () / tuple()
# - dict : {} / dict()
# - set : {} / set ()

# %%
data_set = set()

# %%
print(type(data_set))
# Out:
# <class 'set'>

# %%
brand_group = {"apple", "dell", "lg", "samsung"}

# %%
type(brand_group)
# Out:
# set

# %%
dir(brand_group)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
for brand in brand_group : 
    print(brand)
# Out:
# apple
# dell
# lg
# samsung

# %%
# index
brand_group[0] # index 값을 부여할 수 없어서 오류
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # index
# ----> 2 brand_group[0]
#
# TypeError: 'set' object is not subscriptable

# %%
ppap = set()
print(type(ppap))
# Out:
# <class 'set'>

# %%
ppap = {"pen", "apple", "pineapple", "pen"} # set 은 중복값을 허용하지 않음!

# %%
print(ppap)
# Out:
# {'apple', 'pen', 'pineapple'}

# %%
# set 이라는 자료구조 내 특정 값이 있는지 여부를 판단하는 문법 존재
# set은 애초에 반복적인 값을 허용하지 않기 때문에 set 자료구조에 이미 저장된 요소들은 모두 1번씩 밖에 사용

"apple" in ppap # in 전치사의 역할 : in 뒤에 나오는 set 자료구조 안에 값이 한 번이라도 있으면 true 
"applepen" in ppap
# Out:
# False

# %%
data1 = {"apple", "samsung", "lg"}
data2 = {"samsung", "lg", "xiaomi"}

# %%
data1 & data2 # 교집합
# Out:
# {'lg', 'samsung'}

# %%
data1 | data2 # 합집합 vertical bar
# Out:
# {'apple', 'lg', 'samsung', 'xiaomi'}

# %%
data1 - data2 # 차집합
# Out:
# {'apple'}

# %%
data1 ^ data2 # 부분집합 캐럿
# Out:
# {'apple', 'xiaomi'}

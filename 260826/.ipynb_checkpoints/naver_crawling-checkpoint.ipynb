# %% [markdown]
# 1. 왜 이 목표 및 미션이 필요한가? : 3C 분석 (마케팅 적인 부분이기 때문에 고민X)
# 2. 목표 = : 네이버 포털사이트 내 뉴스 카테고리에서 특정 키워드 검색 시, 나오는 기사 제목을 수집해오기
# 3. 그동안 배웠던 문법 즉, 함수가 먼저 머리속에 나오면 X
# 4.
# 5. 위 목표 및 미션을 해결하기 위한 절차 & 과정 = 프로세스 먼저 그려야함!!!!!!
# 6. 네이버 포털 사이트 > 뉴스 카테고리 : 문법?
# 7. 검색을 희망하는 키워드를 입력 : 첫번째 문법 어떻게 사용?
# 8. 키워드 입력 후 검색하기 버튼 클릭 : 문법?
# 9. 버튼 클릭 된 후 출력되고 있는 기사 제목 스캔
# 10. 기사 제목 스캔 후 상위 10개 기사 제목만 가져와야함

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in C:\Users\user\anaconda3\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (2026.6.17)

# %%
import requests
from bs4 import BeautifulSoup

query = input("검색하고 싶은 키워드를 입력하세요")
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}"

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.fender-ui_228e3bd1.ise_N8_wf_ooMaN2")
# soup > select : 인자값과 동일한 값이기만 하면 몇개든지 찾아와! 

for i, title in enumerate(titles[:10], 1) :
    print(f"{i}. {title.text}")
# Out:
# 검색하고 싶은 키워드를 입력하세요 디지털마케틴ㅇ
# 1. AI와 인간의 상상력이 만나면…부산국제마케팅광고제 개막새 창 열림
# 2. [기고] 마케팅은 이제 소프트웨어가 됐다새 창 열림
# 3. S-OIL, AI시대 디지털 혁신과 액침냉각유 사업 속도새 창 열림
# 4. “제주에서 배운다”… 한경닷컴·이랜드파크 ‘K-Tour LX 콘텐츠 마케팅...새 창 열림
# 5. 메디케이메이트, 중국 디지털 마케팅 연계 외국인환자 유치사업 확대새 창 열림
# 6. 용산 청년, 200만원 무역교육 무료로…AI 마케팅부터 취업까지 지원새 창 열림
# 7. 의사 마음 잡은 제약사 마케팅은 AI보다 '채널'···한미약품 7년째 1위새 창 열림
# 8. [人사이트] 이지혁 블럭스 대표 “자율집행 AI 에이전트로 CRM 마케팅 문...새 창 열림
# 9. [안산소식]'AI 활용 온라인 마케팅' 교육생 모집 등새 창 열림
# 10. LG생건, 미국 '에이본' 매각…디지털 중심으로 북미 사업 재편새 창 열림

# %%
import requests
from bs4 import BeautifulSoup

query = input("검색하고 싶은 키워드를 입력하세요")
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}"

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

news_contents = soup.select("div.sds-comps-vertical-layout.sds-comps-full-layout.vlFp8ERAn58mSKma")

for i, content in enumerate(news_contents[:10], 1) :
    title = content.select_one("a.fender-ui_228e3bd1.ZdTBe0dB_G0DGXFC")
    body = content.select_one("a.fender-ui_228e3bd1.DPWFguOj6E7T6a6U")

    title_text = title.text.strip()
    link = title.get("href")
    body_text = body.text.strip()

    print(f"{i}. {title_text} {link} {body_text}")
# Out:
# 검색하고 싶은 키워드를 입력하세요 데이터 마케팅
# 1. 아시아 최대 부산국제마케팅광고제 개막…AI시대 출품체계 혁신새 창 열림 https://www.yna.co.kr/view/AKR20260826020900051?input=1195m 국제명예상 수상자인 라자 라자만나르를 비롯해 퍼블리시스 런던, 제일기획, 일본 폴라(POLA) 등 세계적인 기업의 현직 전문가들이 기술·데이터·문화 변화에 따른 마케팅 전략과 AI 시대의 창의성 등에 대한 통찰과 해법을 제시한다. 올해 처음 마련한 국가 특집 프로그램의 첫 대상 국가로 필리핀을 선정해... 새 창 열림
# 2. "외국인 5명중 1명 지방공항 이용"...관광공사, '요즘 한국관광 데이터...새 창 열림 https://www.starnewskorea.com/business-life/2026/08/27/2026082716004038629 한국관광공사(사장 박성혁, 이하 공사)는 27일 더 플라자 호텔 서울에서 '제2회 요즘, 한국관광 데이터 세미나'를 개최했다. 지난 5월 첫 세미나에 이어... 공사 타이베이지사가 부산 중심 마케팅을 남부지역으로 단계적으로 확대해 온 결과, 김해공항을 통한 대만 입국자는 2023년 대비 2025년 157.5% 증가했다.... 새 창 열림
# 3. "SNS 데이터로 아시아 홀렸다"…피처링, 포브스 100대 유망기업 선정새 창 열림 https://www.mt.co.kr/future/2026/08/26/2026082609142695415 2019년 설립된 피처링은 자체 소셜미디어 데이터 엔진 '피처링 AI'를 기반으로 데이터 기반 인플루언서 마케팅 사업을 전개하고 있다. 올인원 인플루언서 마케팅 솔루션 '피처링'과 기업 맞춤형 소셜데이터 분석 플랫폼 '피처링 엔터프라이즈'를 1만6000여개 기업에 공급하고 있다. 피처링은 올해 SNS... 새 창 열림
# 4. ‘챗GPT vs 제미나이’...돈 되는 한국 시장 놓고 마케팅 전쟁새 창 열림 https://www.chosun.com/economy/tech_it/2026/08/27/T62R7L2VHFCKNBRPYONNM27WYM/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news 최근 오픈AI와 구글이 국내 AI 이용자를 확보하기 위해 대대적인 마케팅에 나서고 있다. 유명 유튜브 채널을 통해 기능을 소개하거나 동영상 광고를... 앱·결제 데이터 분석 기업 와이즈앱·리테일에 따르면 지난 7월 국내에서 가장 많이 사용한 AI 챗봇 앱은 챗GPT로 MAU(월간 활성 사용자 수)가... 새 창 열림
# 5. [기고] 마케팅은 이제 소프트웨어가 됐다새 창 열림 https://www.edaily.co.kr/News/Read?newsId=03188166645551256&mediaCodeNo=257&utm_source=naver&utm_medium=referral&utm_campaign=news_syndication&utm_content=original_article 검색엔진 최적화(SEO)와 AEO·GEO, 고객관계관리(CRM), 앱스토어 최적화(ASO), 퍼포먼스 마케팅(UA), 데이터 엔지니어링 등 디지털 마케팅 전 영역을 아우른다. NNT는 삼성전자, LG전자, 현대자동차, 배달의민족, 무신사 등 주요 기업과 350건 이상의 프로젝트를 수행하며 AI와 데이터를 실제 비즈니스 성장에... 새 창 열림
# 6. "피자 먹고 게임 굿즈 챙긴다" 식품·외식업계, 팬덤 마케팅 활발새 창 열림 https://www.newsis.com/view/NISX20260826_0003763139 (IP) 마케팅에 힘을 싣고 있다. 26일 업계에 따르면 인기 게임이나 캐릭터를 활용한 한정판 메뉴와 굿즈를 선보이는 것을 넘어 게임 세계관을 매장에 구현하는 등 팬덤을 실제 구매와 브랜드 경험으로 연결하려는 움직임이 이어지고 있다. 외식 가격 상승세가 이어지면서 소비자들의 부담은 여전하다. 국가데이터... 새 창 열림
# 7. [게임스컴2026] 엔씨, 모바일 캐주얼 글로벌 공략, 옵티플로우’로 데이...새 창 열림 https://www.gamechosun.co.kr/webzine/article/view.php?no=224651 옵티플로우는 엔씨 포트폴리오에 포함된 여러 스튜디오의 데이터와 노하우를 결합하는 플랫폼이다. 게임을 수익화하고 글로벌 시장에 선보이는 방법을... 일부 스튜디오는 수익성 있게 마케팅에 투자할 충분한 자원이 없을 수 있다. 엔씨가 이를 지원할 수 있다. 두 번째는 전문성이다. 나와 팀원들은 세계적인... 새 창 열림
# 8. 경북문화관광공사, 싱가포르 NATAS서 경북 관광객 유치 마케팅 진행새 창 열림 http://www.metroseoul.co.kr/article/20260825500592 행사 기간 경북 부스 이벤트에는 1000명 이상이 참여했으며, 공사는 경북 관광 정보를 지속적으로 전달할 수 있는 채널과 향후 싱가포르 마케팅 전략에 활용할 데이터를 확보했다. 한국관광공사의 2025년 국가별 방한 현황 통계에 따르면 싱가포르 외래 관광객은 39만9635명이며 재방문율은 61%에... 새 창 열림
# 9. 룰루랩, ‘2026 서울뷰티위크’서 AI·데이터 기반 K-뷰티테크 선도새 창 열림 https://sports.khan.co.kr/article/202608270618003?pt=nv 이의소 루디언트 마케팅 총괄 이사는 “K-뷰티의 다음 경쟁력은 좋은 제품을 만드는 것을 넘어, AI와 데이터를 통해 소비자 한 사람 한 사람에게 가장 적합한 제품과 서비스를 연결하는 데 있다”​며 “룰루랩은 60여 개국에서 축적한 500만 건 이상의 피부 데이터와 자체 AI 기술을 기반으로 화장품... 새 창 열림
# 10. “나랑드사이다, 리센느 발탁 한 달간 매출 48% 급증…K팝 마케팅 성공...새 창 열림 http://www.globalepic.co.kr/view.php?ud=20260827113635289048439a4874_29 동아오츠카가 K팝 스타의 영향력을 활용한 마케팅 전략으로 제로 음료 시장에서 대중적 관심을 더욱 끌어올리는 데 성공한 것으로 평가된다.... 이 수치는 주요 온라인 채널, 동아오츠카 자사몰, 편의점 등 다양한 유통 채널의 판매 데이터를 종합하여 산출된 것이다. 리센느라는 신선한 얼굴과 함께한... 새 창 열림

# %% [markdown]
# * 직전 혹은 최근 작성했던 코드가 정상적으로 작동하지 않는다.
# * 왜 문제가 발행했을까
# - 클라이언트 & 서버 통신 정상적이지 못하다(네이버 측에서 데이터 X)
#   soup = requests.get(url)
#   print(soup.text) : 클라이언트, 서버 통신 환경 = status -> 200, 300, 400, 500
# - 서버에서는 데이터를 정상적으로 주고 있지만, 인터넷 환경이 좋지 못할 수 있다.(우리 내부 인터넷 통신망)
# - print(soup.text)
# - 네이버, 인터넷 망 둘 다 문제가 없다면 내부 코드 상의 변화(네이버 웹사이트 자체적인 코드 수정. 업데이트. 리뉴얼)

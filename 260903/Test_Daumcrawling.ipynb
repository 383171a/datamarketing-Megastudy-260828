# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech?nil_profile=mini&nil_src=news"

headers = {
    "User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"
}

response = requests.get(url, headers)
response.encoding= "utf-8"
soup = BeautifulSoup(response.text, "html.parser")


for i, title_text in enumerate(title[:10], 1) :
    title = title_text.select_one("div.cont_thumb")
    print(f"{i}. {title_text}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 15
#      11 response.encoding= "utf-8"
#      12 soup = BeautifulSoup(response.text, "html.parser")
#      13
#      14
# ---> 15 for i, title_text in enumerate(title[:10], 1) :
#      16     title = title_text.select_one("div.cont_thumb")
#      17     print(f"{i}. {title_text}")
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2484, in Tag.__getitem__(self, key)
#    2481 def __getitem__(self, key: str) -> _AttributeValue:
#    2482     """tag[key] returns the value of the 'key' attribute for the Tag,
#    2483     and throws an exception if it's not there."""
# -> 2484     return self.attrs[key]
#
# KeyError: slice(None, 10, None)

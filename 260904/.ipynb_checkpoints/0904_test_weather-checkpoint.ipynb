# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/forecast/overall/short-term.do"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

announce = soup.select_one("div.cmp-view-announce")
news_announce = announce.text.strip()

header = soup.select_one("div.cmp-view-header.cmp-view-header-center")
news_header = header.text.strip()


print(news_contents)
# Out:
# 2026년 09월 04일 (금)요일 17:00 발표
# (총괄예보관: 한상은)

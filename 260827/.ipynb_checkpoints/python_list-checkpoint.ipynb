# %% [markdown]
# 1. 파일썬 일반자료형
# - int
# - float
# - str (*index, 슬라이싱)
# - bool
#
# 2. 파이썬 데이터(자료)구조 (변수 선언 후 값을 할당하기는 하나, 단수의 값이 아닌 복수의 값을 할당 -> 복잡한 데이터 구조를 설계. 설정)
# - list : [] | list() -> 둘 다 리스트 자료구조 생성 가능!
# - 인덱스를 가지고 있음 (작동 원리 = 문자열과 같음)
# - 리스트 전용 메서드 및 함수 : len() -> 함수, insert(), append(), extend(), pop(), remove() -> 메서드
# - 명령어 = 예약어 : del
# - 정렬 메서드 : sort(), reverse()
# - 구분 메서드 : split() -> 복제본을 만들어서 사용!!
# - 슬라이싱 기능

# %%
location = ["서울시", "경기도", "인천시"] # 리스트라는 자료 구조를 할당했다. 
location01 = "서울시" 
# num01 = 7
# 리스트 -> 인덱스를 가지고 있는데, 사용방법이 문자열과 거의 비슷 
print(type(location))
# Out:
# <class 'list'>

# %%
# 문자열 & 리스트 (안에 들어가있는 속성 원리가 거의 비슷)

# %%
print(location[0])
print(location[1])
print(location[2])
# Out:
# 서울시
# 경기도
# 인천시

# %%
location.append("부산시")

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '대전시', '부산시', '부산시', '부산시', '부산시', '부산시']

# %%
location.insert(3,"대전시")

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '대전시', '부산시', '부산시']

# %%
location.extend(["울산시", "대구시"])

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '대전시', '부산시', '부산시', '부산시', '부산시', '부산시', '울산시', '대구시']

# %%
location[len(location)-1]
# Out:
# '대구시'

# %%
location.pop() # pop 메서드 안에 아무런 인자값 x -> 무조건 마지막 번째 값 제거
# Out:
# '대구시'

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '대전시', '부산시', '부산시', '부산시', '부산시', '부산시', '울산시']

# %%
location.insert(2, "강원도")

# %%
location
# Out:
# ['서울시',
#  '경기도',
#  '강원도',
#  '강원도',
#  '강원도',
#  '강원도',
#  '인천시',
#  '대전시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '울산시']

# %%
location.pop(2)
# Out:
# '강원도'

# %%
location
# Out:
# ['서울시',
#  '경기도',
#  '강원도',
#  '강원도',
#  '강원도',
#  '인천시',
#  '대전시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '부산시',
#  '울산시']

# %%
location.pop(-3)
# Out:
# '부산시'

# %%
location
# Out:
# ['서울시', '경기도', '강원도', '강원도', '강원도', '인천시', '대전시', '부산시', '부산시', '부산시', '울산시']

# %%
location.remove("인천시")

# %%
location
# Out:
# ['서울시', '경기도', '강원도', '강원도', '강원도', '대전시', '부산시', '부산시', '부산시', '울산시']

# %%
location[:] # 슬라이싱 기능, 시작 혹은 종료값 - 실제 리스트 첫번째 혹은 마지막 번째 동일
# Out:
# ['서울시', '경기도', '강원도', '강원도', '강원도', '대전시', '부산시', '부산시', '부산시', '울산시']

# %%
location
# Out:
# ['서울시', '경기도', '강원도', '강원도', '강원도', '대전시', '부산시', '부산시', '부산시', '울산시']

# %%
del location[0]

# %%
location
# Out:
# ['경기도', '강원도', '강원도', '강원도', '대전시', '부산시', '부산시', '부산시', '울산시']

# %%
list01 = [1, 2, 3]

# %%
type(list01)
# Out:
# list

# %%
# 리스트 자료구조가 필요한 건 사실이지만, 그렇다고 지금 당장 넣어놓을 수 있는 값은 없는 경우!!

# %%
list02 = list()

# %%
type(list02)
# Out:
# list

# %%
numbers = [2, 1, 4, 3] 
print(numbers)
# Out:
# [2, 1, 4, 3]

# %%
# 정렬 기능 사용
# 오름차순정렬 : 1-> 10
# 내림차순정렬 : 10 -> 1

numbers.sort() # 오름 차순 정렬

# %%
numbers
# Out:
# [1, 2, 3, 4]

# %%
numbers.reverse()

# %%
numbers
# Out:
# [1, 2, 3, 4]

# %%
text_something01 = "python is easy"
text_something01.split()
# Out:
# ['python', 'is', 'easy']

# %%
text_something01
# Out:
# 'python is easy'

# %%
# sort, reverse => 원본값도 같이 변경 
# split => 원본값을 바꾸지 x
